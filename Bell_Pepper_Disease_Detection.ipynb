# %%
# !nvidia-smi
# Out:
# Tue Nov 28 06:35:06 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   65C    P8    11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# %cd '/content/drive/MyDrive/Bell_Pepper_Leaf_Disease.v1i.yolov8/'
# Out:
# /content/drive/MyDrive/Bell_Pepper_Leaf_Disease.v1i.yolov8

# %%
# !pip install ultralytics

# %%
open('data.yaml')
# Out:
# <_io.TextIOWrapper name='data.yaml' mode='r' encoding='UTF-8'>

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.219 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.3/78.2 GB disk)

# %% [markdown]
# ## Training

# %%
# !yolo task = detect mode=train model = yolov8s.pt data=/content/drive/MyDrive/Bell_Pepper_Leaf_Disease.v1i.yolov8/data.yaml \
    epochs = 50 imgsz = 640 batch = 8 project=/content/drive/MyDrive/Bell_Pepper_Leaf_Disease.v1i.yolov8/training_results \
    name=bell_pepper
# Out:
# Ultralytics YOLOv8.0.219 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ## Inferencing

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/Bell_Pepper_Leaf_Disease.v1i.yolov8/training_results/bell_pepper2/weights/best.pt \
conf = 0.6 source=/content/drive/MyDrive/Bell_Pepper_Leaf_Disease.v1i.yolov8/data/test/images
# Out:
# Ultralytics YOLOv8.0.219 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/35 /content/drive/MyDrive/Bell_Pepper_Leaf_Disease.v1i.yolov8/data/test/images/BacterialSpot-101-_JPG.rf.ca1dbf91481fd6cc7bcf9d80263c36b0.jpg: 640x640 1 bacterial_spot, 23.8ms
# image 2/35 /content/drive/MyDrive/Bell_Pepper_Leaf_Disease.v1i.yolov8/data/test/images/BacterialSpot-103-_JPG.rf.121a7546baa19d40a9ac03ec9ee6bcce.jpg: 640x640 5 bacterial_spots, 16.3ms
# image 3/35 /content/drive/MyDrive/Bell_Pepper_Leaf_Disease.v1i.yolov8/data/test/images/BacterialSpot-11-_JPG.rf.06135912bf0188972eece377c3e8bdc5.jpg: 640x640 1 bacterial_spot, 16.3ms
# image 4/35 /content/drive/MyDrive/Bell_Pepper_Leaf_Disease.v1i.yolov8/data/test/images/BacterialSpot-110-_JPG.rf.ea689e52aaf605c23198ce4a1803109b.jpg: 640x640 2 bacterial_spots, 16.3ms
# ...

# %%
# !cp -r /content/drive/MyDrive/Bell_Pepper_Leaf_Disease.v1i.yolov8/runs/detect/predict2 /content/drive/MyDrive/Bell_Pepper_Leaf_Disease.v1i.yolov8/output
